# %%
# !pip install --upgrade setuptools
# !pip install -e .

# %%
# %conda install ipykernel
# !pip install -r requirements.txt
# %conda install -c conda-forge ta-lib
# !pip install torch
from blockhouse_ml.ml_prod import run_equities_sell_inference
from blockhouse_ml.ml_prod import run_equities_buy_inference
# Out:
# BuyEquityModels

# %%
## Equity Sell inference
# results = run_equities_sell_inference('TSLA',inventory=1000)
results = run_equities_buy_inference('TSLA',inventory=10000)
# Out:
# Merged data saved to merged_data_TSLA_2024-09-08_2024-09-10.csv
# LOGGING: Adding Forecasts to data...
# LOGGING: Generating Schedule...
# large
# large cap, large scenario model selected
# model_save_path BuyEquityModels/model_large_cap_large.h5
# loading latest model
# ------------------------------------------------Class resetted------------------------------------------------
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ...

# %%
results
# Out:
# [{'step': 2,
#   'timestamp': '2024-09-10 19:29:00',
#   'order_type': 'Limit',
#   'volume': 1505,
#   'execution_price': 221.8182476754401,
#   'reward': -10225.022670987159},
#  {'step': 3,
#   'timestamp': '2024-09-10 20:00:00',
#   'order_type': 'Limit',
#   'volume': 1981,
#   'execution_price': 224.99572811841057,
#   'reward': -10396.856356249356},
#  {'step': 4,
#   'timestamp': '2024-09-11 13:30:00',
#   'order_type': 'Limit',
#   'volume': 317,
#   'execution_price': 225.97649761436304,
#   'reward': -10388.070568590687},
#  {'step': 5,
#   'timestamp': '2024-09-11 14:21:00',
#   'order_type': 'Market',
#   'volume': 439,
#   'execution_price': 226.88339816687872,
#   'reward': -10723.787115356801},
#  {'step': 6,
#   'timestamp': '2024-09-11 15:12:00',
#   'order_type': 'Market',
#   'volume': 170,
#   'execution_price': 227.70354779571815,
#   'reward': -10729.1548214301},
#  {'step': 7,
#   'timestamp': '2024-09-11 15:59:00',
#   'order_type': 'Limit',
# ...
