# %%
from datetime import datetime
import pytz

from GordonRitter.utils.pipeline import OptimalBetSizeInference

# Create the Inference class object
obj = OptimalBetSizeInference(data_dir='Data')

rs = obj.run_pipeline_with_order_types(
    ticker='AAPL',
    end_timestamp=datetime.now(pytz.UTC).strftime('%Y-%m-%d'),
    timeframe=390,
    inventory=10000,
    bet_sz_model_dir='Models/bet_sizing_v1')
# Out:
# /home/malhar/Workspace/Blockhouse/Blockhouse-ML/GordonRitter/utils/pipeline.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp'] = pd.to_datetime(df['timestamp'])
# /home/malhar/Workspace/Blockhouse/Blockhouse-ML/GordonRitter/utils/pipeline.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['timestamp'].dt.date
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/blockhouse/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bid'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 9
#       6 # Create the Inference class object
#       7 obj = OptimalBetSizeInference(data_dir='Data')
# ----> 9 rs = obj.run_pipeline_with_order_types(
#      10     ticker='AAPL',
#      11     end_timestamp=datetime.now(pytz.UTC).strftime('%Y-%m-%d'),
#      12     timeframe=390,
#      13     inventory=10000,
#      14     bet_sz_model_dir='Models/bet_sizing_v1')
#
# File ~/Workspace/Blockhouse/Blockhouse-ML/GordonRitter/utils/pipeline.py:227, in OptimalBetSizeInference.run_pipeline_with_order_types(self, ticker, end_timestamp, timeframe, inventory, bet_sz_model_dir)
#     221 start_timestamp = (datetime.strptime(end_timestamp, '%Y-%m-%d') - timedelta(days=2)).strftime('%Y-%m-%d')
#     222 data = self.data_client.fetch_and_merge_data(
#     223     ticker,
#     224     start_date=start_timestamp,
#     225     end_date=end_timestamp)
# --> 227 optimal_timings = self.optimal_time_generation(data, steps_forward=timeframe)
#     228 optimal_bet_sizes = self.optimal_bet_sizing_with_order_type(
#     229     data=optimal_timings,
#     230     model_dir=bet_sz_model_dir,
#     231     initial_invetory=inventory,
#     232     optm_pts_per_day=20)
#     233 return optimal_bet_sizes
#
# File ~/Workspace/Blockhouse/Blockhouse-ML/GordonRitter/utils/pipeline.py:84, in OptimalBetSizeInference.optimal_time_generation(self, df, steps_forward)
#      81     forecast=np.array(forecast)
#      82     return forecast
# ---> 84 ask_price_1_forecast = non_recurrent_hist_mean(df, df_forecast, 'ask_price_1', 3)
#      85 ask_size_1_forecast = non_recurrent_hist_mean(df, df_forecast, 'ask_size_1', 3).astype(int)
#      87 df_forecast['ask_price_1'] = ask_price_1_forecast
#
# File ~/Workspace/Blockhouse/Blockhouse-ML/GordonRitter/utils/pipeline.py:79, in OptimalBetSizeInference.optimal_time_generation.<locals>.non_recurrent_hist_mean(train, test, col, window_size)
#      77     historical_mean = past_data.mean()
#      78     if np.isnan(historical_mean):
# ---> 79         historical_mean = train['bid'].iloc[-1] # last close price #change to bid_price_1
#      80     forecast.append(historical_mean)
#      81 forecast=np.array(forecast)
#
# File ~/miniconda3/envs/blockhouse/lib/python3.9/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/miniconda3/envs/blockhouse/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'bid'

# %%
rs
# Out:
# [            timestamp  volume order_type price
#  0 2024-11-04 17:06:00    2760     market  None
#  1 2024-11-04 17:07:00     263     market  None
#  2 2024-11-04 18:17:00       0     market  None
#  3 2024-11-04 18:18:00       0     market  None
#  4 2024-11-04 18:35:00       0     market  None
#  5 2024-11-04 18:36:00       0     market  None
#  6 2024-11-04 18:37:00    6977     market  None]
