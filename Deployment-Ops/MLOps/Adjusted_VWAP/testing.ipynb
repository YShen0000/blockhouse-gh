# %%
# !python inference.py

# %%
# !pip uninstall blockhouse-ml

# %%
import time

start_t = time.perf_counter()

from inference import model_fn, input_fn, predict_fn, output_fn
import json
model = model_fn()

# Simulate a request body
request_body = json.dumps({
    "ticker": "AAPL",
    "action": "sell",
    "inventory": 1,
    "timeframe": 390
})

# Run the inference process
input_data = input_fn(request_body, 'application/json')
prediction = predict_fn(input_data, model)
output = output_fn(prediction, 'application/json')

print("Prediction Result:", output)

print(f"Time taken: {time.perf_counter() - start_t} seconds")
# Out:
# Initializing model
# INFO:inference:Initializing model
# Model initialized in 6.00004568696022e-07 seconds!!!
# INFO:inference:Model initialized in 6.00004568696022e-07 seconds!!!
# Deserializing the input data.
# INFO:inference:Deserializing the input data.
# Input data: {'ticker': 'AAPL', 'action': 'sell', 'inventory': 1, 'timeframe': 390}
# INFO:inference:Input data: {'ticker': 'AAPL', 'action': 'sell', 'inventory': 1, 'timeframe': 390}
# Running sell inference for ticker: AAPL
# INFO:inference:Running sell inference for ticker: AAPL
# inside ohlcv
# Start date in OHLCV: 2024-10-24
# End date for OHLCV: 2024-10-25
# 1.0676264000067022
# Got the response
# LOGGING: Adding 390-step OHLCV Forecasts to data...
# Last timestamP: 2024-10-25 15:00:00
# Current time: 2024-10-25 13:30:00+00:00
# c:\Users\yashv\miniconda3\envs\MLProj\lib\site-packages\statsmodels\tsa\holtwinters\model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# ...

# %%
# !python deployment_utils/deployment.py \
  --region "us-east-1" \
  --model_name "adjusted-vwap-v3" \
  --endpoint_name "prod-adjusted-vwap-v3" \
  --endpoint_config_name "prod-adjusted-vwap-v3" \
  --version 1 \
  --sagemaker_role "arn:aws:iam::433046797920:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole" \
  --account_id "433046797920" \
  --image_tag "deploy-test3" \
  --model_files Adjusted_VWAP inference.py Adjusted_VWAP/requirements.txt \
  --instance_type "ml.m5.xlarge"
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Files to package:  ['Adjusted_VWAP', 'inference.py', 'Adjusted_VWAP/requirements.txt']
# Adjusted_VWAP
# inference.py
# requirements.txt
# model created:  arn:aws:sagemaker:us-east-1:433046797920:model/adjusted-vwap-v3
#  Endpoint name: prod-adjusted-vwap-v3, model name: adjusted-vwap-v3 created successfully.
# {'InferenceComponentArn': 'arn:aws:sagemaker:us-east-1:433046797920:inference-component/adjusted-vwap-v3-inference-component', 'ResponseMetadata': {'RequestId': 'c9221420-6f31-47aa-a244-61caa9a3601d', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c9221420-6f31-47aa-a244-61caa9a3601d', 'content-type': 'application/x-amz-json-1.1', 'content-length': '125', 'date': 'Mon, 28 Oct 2024 18:26:55 GMT'}, 'RetryAttempts': 0}}
# ...

# %%
# !python deployment_utils/deployment.py \
  --region "us-east-1" \
  --model_name "adjusted-vwap-BL-report-1-new" \
  --endpoint_name "prod-adjusted-vwap-BL-report-1-new" \
  --endpoint_config_name "prod-adjusted-vwap-BL-report-1-new" \
  --version 1 \
  --sagemaker_role "arn:aws:iam::433046797920:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole" \
  --account_id "433046797920" \
  --image_tag "deploy-test3" \
  --model_files Adjusted_VWAP inference.py Adjusted_VWAP/requirements.txt \
  --instance_type "ml.g4dn.2xlarge"
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\Prasanna\AppData\Local\sagemaker\sagemaker\config.yaml
# Files to package:  ['Adjusted_VWAP', 'inference.py', 'Adjusted_VWAP/requirements.txt']
# Adjusted_VWAP
# inference.py
# requirements.txt
# model created:  arn:aws:sagemaker:us-east-1:433046797920:model/adjusted-vwap-BL-report-1-new
#  Endpoint name: prod-adjusted-vwap-BL-report-1-new, model name: adjusted-vwap-BL-report-1-new created successfully.
# Endpoint created: arn:aws:sagemaker:us-east-1:433046797920:endpoint/prod-adjusted-vwap-BL-report-1-new
# Inference component created: adjusted-vwap-BL-report-1-new-inference-component

# %%
# !python deployment_utils/deployment.py \
  --region "us-east-1" \
  --model_name "async-adjusted-vwap-HW-report-1" \
  --endpoint_name "async-prod-adjusted-vwap-HW-report-1" \
  --endpoint_config_name "async-prod-adjusted-vwap-HW-report-1" \
  --version 1 \
  --sagemaker_role "arn:aws:iam::433046797920:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole" \
  --account_id "433046797920" \
  --image_tag "deploy-test3" \
  --model_files Adjusted_VWAP inference.py Adjusted_VWAP/requirements.txt \
  --instance_type "ml.m5.4xlarge"
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Files to package:  ['Adjusted_VWAP', 'inference.py', 'Adjusted_VWAP/requirements.txt']
# Adjusted_VWAP
# inference.py
# requirements.txt
# model created:  arn:aws:sagemaker:us-east-1:433046797920:model/async-adjusted-vwap-HW-report-1
# An error occurred while creating the endpoint: An error occurred (ResourceLimitExceeded) when calling the CreateEndpoint operation: The account-level service limit 'ml.m5.4xlarge for endpoint usage' is 1 Instances, with current utilization of 1 Instances and a request delta of 1 Instances. Please use AWS Service Quotas to request an increase for this quota. If AWS Service Quotas is not available, contact AWS support to request an increase for this quota.
# Traceback (most recent call last):
# ...

# %%
# !python deployment_utils/deployment.py \
  --region "us-east-1" \
  --model_name "async-adjusted-vwap-HW-report-1" \
  --endpoint_name "async-prod-adjusted-vwap-HW-report-1" \
  --endpoint_config_name "async-prod-adjusted-vwap-HW-report-1" \
  --version 1 \
  --sagemaker_role "arn:aws:iam::433046797920:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole" \
  --account_id "433046797920" \
  --image_tag "deploy-test3" \
  --model_files Adjusted_VWAP inference.py Adjusted_VWAP/requirements.txt \
  --instance_type "ml.m5.4xlarge"
